# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
#NLP libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/lukaszmarchlewicz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/lukaszmarchlewicz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
ls ../output
# Out:
# comments_youtube.csv  video_youtube.csv

# %% [markdown]
# ### Import Data (video)

# %%
video_df = pd.read_csv('../output/video_youtube.csv')

# %% [markdown]
# ### Check for empty values

# %%
video_df.isnull().sum()
# Out:
# video_id            0
# channelTitle        0
# title               0
# description        29
# tags              111
# publishedAt         0
# viewCount           0
# likeCount           5
# favouriteCount    367
# commentCount        0
# duration            0
# definition          0
# caption             0
# dtype: int64

# %%
video_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        367 non-null    object
#  1   channelTitle    367 non-null    object
#  2   title           367 non-null    object
#  3   description     338 non-null    object
#  4   tags            256 non-null    object
#  5   publishedAt     367 non-null    object
#  6   viewCount       367 non-null    int64
#  7   likeCount       362 non-null    float64
#  8   favouriteCount  0 non-null      float64
#  9   commentCount    367 non-null    int64
#  10  duration        367 non-null    object
#  11  definition      367 non-null    object
#  12  caption         367 non-null    bool
# dtypes: bool(1), float64(2), int64(2), object(8)
# memory usage: 34.9+ KB

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']

video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
video_df.head()
# Out:
#       video_id       channelTitle  \
# 0  sHqNiID4VY0  Python Simplified
# 1  jIZWlmGPpWA  Python Simplified
# 2  9utmI959cBo  Python Simplified
# 3  Df599JpxHBY  Python Simplified
# 4  p3tSLatmGvU  Python Simplified
#
#                                                title  \
# 0  DON'T USE AI - MAKE AI! A Bright Future Where ...
# 1  My Thoughts On ChatGPT - PULL THE PLUG BEFORE ...
# 2  You are only as productive as your cat allows ...
# 3  Vote now!!! upcoming tutorial poll‼️ #shorts #...
# 4  Convert GUI App to Real Program -  Python to e...
#
#                                          description tags  \
# 0  Folks, the future of our industry is a million...  NaN
# 1  🛑Good News!! I found a solution!!! 🛑\nPlease c...  NaN
# 2                                                NaN  NaN
# 3                                                NaN  NaN
# 4  You've just made a beautiful GUI app with Pyth...  NaN
#
#             publishedAt  viewCount  likeCount  favouriteCount  commentCount  \
# 0  2023-02-13T17:25:34Z    14330.0     1540.0             NaN         296.0
# 1  2023-02-07T18:06:29Z    39970.0     2740.0             NaN        1186.0
# 2  2023-02-06T17:30:46Z     2639.0      246.0             NaN          19.0
# 3  2023-01-31T19:50:31Z     7211.0      616.0             NaN          27.0
# 4  2023-01-27T15:00:40Z    74655.0     2794.0             NaN         218.0
#
#    duration definition  caption
# 0   PT5M39S         hd     True
# 1  PT12M29S         hd     True
# 2     PT31S         hd    False
# 3     PT36S         hd    False
# 4  PT23M27S         hd     True

# %% [markdown]
# ### Enriching data

# %%
# Create publish day (in the week) column
from dateutil import parser

video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
# convert duration to seconds
import isodate

video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
# Add number of tags
video_df['tagsCount'] = video_df['tags'].apply(lambda x: 0 if x is np.nan else len(x))

# %%
# Comments and likes per 1000 view ratio
video_df['likeRatio'] = video_df['likeCount']/ video_df['viewCount'] * 1000
video_df['commentRatio'] = video_df['commentCount']/ video_df['viewCount'] * 1000

# %%
# Title character length
video_df['titleLength'] = video_df['title'].apply(lambda x: len(x))

# %% [markdown]
# ### Views distribution per channel

# %%
plt.rcParams['figure.figsize'] = (18, 6)
sns.violinplot(data = video_df, x = 'channelTitle', y='viewCount', palette = 'pastel')
plt.title('Views per channel', fontsize = 14)
plt.show()

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "commentCount", y = "viewCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "likeCount", y = "viewCount", ax=ax[1]);

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "commentRatio", y = "viewCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "likeRatio", y = "viewCount", ax=ax[1]);

# %%
sns.histplot(data=video_df[video_df['durationSecs'] < 10000], x="durationSecs", bins=30)
# Out:
# <AxesSubplot: xlabel='durationSecs', ylabel='Count'>

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "durationSecs", y = "commentCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "durationSecs", y = "likeCount", ax=ax[1])
# Out:
# <AxesSubplot: xlabel='durationSecs', ylabel='likeCount'>

# %%
sns.scatterplot(data = video_df, x = "titleLength", y = "viewCount")
# Out:
# <AxesSubplot: xlabel='titleLength', ylabel='viewCount'>

# %% [markdown]
# ### Wordcloud for video titles

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words)

# %%
def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %% [markdown]
# ### Upload schedule

# %%
day_df = pd.DataFrame(video_df['pushblishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=0)

# %% [markdown]
# ### Wordcloud comments

# %%
comments_df = pd.read_csv('../output/comments_youtube.csv')
stop_words = set(stopwords.words('english'))
comments_df['comments_no_stopwords'] = comments_df['comments'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in comments_df['comments_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words)

# %%
wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)
